# %%
import numpy as np
import pandas as pd

# %%
df_results_dp_en = pd.read_csv('../results/deeplearning_en.csv').drop('Unnamed: 0', axis=1)

# %%
df_results_dp_pt = pd.read_csv('../results/deeplearning_pt.csv').drop('Unnamed: 0', axis=1)

# %%
df_results_lex = pd.read_csv('../results/lexicon.csv').drop('Unnamed: 0', axis=1)

# %%
(df_results_dp_en != df_results_dp_pt).sum().sum()
# Out:
# 0

# %%
annotation_paths = [
    '../tweets_01-15mar.csv',
    '../tweets_16-31mar.csv',
    '../tweets_01-15abr.csv',
    '../tweets_16-30abr.csv',
    '../tweets_01-15mai.csv',
    '../tweets_16-31mai.csv',
]

# %%
df_temp = pd.read_csv(annotation_paths[0])

# %%
df_temp
# Out:
#                      id                       date         username  \
# 0   1238977731515342850  2020-03-14 23:58:04+00:00         beegarc_
# 1   1238973281119678464  2020-03-14 23:40:23+00:00  svndownsyndrome
# 2   1238971353161764870  2020-03-14 23:32:44+00:00  Micaela71916755
# 3   1238969503557525509  2020-03-14 23:25:23+00:00  mafalldabatista
# 4   1238968644870291457  2020-03-14 23:21:58+00:00         beegarc_
# 5   1238968014080479236  2020-03-14 23:19:28+00:00         mhoergan
# 6   1238963771781111808  2020-03-14 23:02:36+00:00    porfiriojoao1
# 7   1238962004049698821  2020-03-14 22:55:35+00:00       drewzbiebs
# 8   1238960829925646337  2020-03-14 22:50:55+00:00       TONYS4V4G3
# 9   1238959858336108545  2020-03-14 22:47:03+00:00        arrobaben
# 10  1238955027198291968  2020-03-14 22:27:51+00:00        joaorluz_
# 11  1238953729354801153  2020-03-14 22:22:42+00:00     belavfreitas
# 12  1238951821516955649  2020-03-14 22:15:07+00:00         Vamu_Ver
# ...
