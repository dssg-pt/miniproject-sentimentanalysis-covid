# %%
import pandas as pd

df = pd.read_csv('noticias_observador_fev_a_junho.csv')

df
# Out:
#        Unnamed: 0        Data  \
# 0               0  2020-02-01
# 1               1  2020-02-01
# 2               2  2020-02-01
# 3               3  2020-02-01
# 4               4  2020-02-01
# ...           ...         ...
# 28730        5552  2020-06-30
# 28731        5553  2020-06-30
# 28732        5554  2020-06-30
# 28733        5555  2020-06-30
# 28734        5556  2020-06-30
#
#                                                   Titulo  \
# 0             Coronavírus. Portugueses ficam 14 dias ...
# 1               Wuhan Coronavírus: afinal, qual o risco?
# 2             Como o coronavírus afeta fabricantes de...
# 3             Centenas são repatriados a partir de Wuhan
# 4                  Vídeo mostra a origem do coronavírus?
# ...                                                  ...
# 28730         Supremo autoriza Governo a dar ajuda à TAP
# 28731         MAI: Algarve deve ter "particular exigê...
# 28732           São Paulo autoriza a reabertura de bares
# ...

# %%
df['Titulo'].nunique()
# Out:
# 12510
